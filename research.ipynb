# %% [markdown]
# # Project Research

# %%
import pandas as pd

# %%
import os
from SPARQLWrapper import SPARQLWrapper, JSON


FILE_NAME = 'requests.sparql'

# Function to load queries from the file
def load_queries(file_name=FILE_NAME):
    # Dynamically construct the file path relative to the current script
    current_dir = os.path.dirname('kg_models/')  # Directory of the current script
    file_path = os.path.join(current_dir, file_name)

    # Check if the file exists
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"Queries file not found: {file_path}")

    # Read the queries from the file
    with open(file_path, "r") as f:
        content = f.read()

    queries = {}
    query_blocks = content.split("\n\n")  # Separate queries by empty lines
    for block in query_blocks:
        lines = block.strip().split("\n")
        query_name = lines[0].strip()
        query_body = "\n".join(lines[1:]).strip()
        queries[query_name] = query_body

    return queries


# Function to execute a query
def execute_query(query, location_name):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
    query = query.replace("CITY_NAME", location_name)  # Replace placeholder with location name
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    try:
        results = sparql.query().convert()
        return results["results"]["bindings"]
    except Exception as e:
        print(f"Error executing query: {e}")
        return []


def get_city_info(queries, location_name):
    city_info_query = queries.get("CITY_INFO_QUERY")
    city_info_results = execute_query(city_info_query, location_name)
    city_info = []
    for result in city_info_results:
        city_info.append({
            "city": result.get("city", {}).get("value", None),
            "population": result.get("population", {}).get("value", None),
            "area": result.get("area", {}).get("value", None),
        })
    return city_info

# Function to get cultural sites
def get_cultural_sites(queries, location_name):
    cultural_sites_query = queries.get("CULTURAL_SITES_QUERY")
    cultural_sites_results = execute_query(cultural_sites_query, location_name)
    cultural_sites = []
    for result in cultural_sites_results:
        cultural_sites.append({
            "siteLabel_en": result.get("siteLabel_en", {}).get("value", None),
            "siteLabel_de": result.get("siteLabel_de", {}).get("value", None),
            "description_en": result.get("description_en", {}).get("value", None),
            "description_de": result.get("description_de", {}).get("value", None),
            "image": result.get("image", {}).get("value", None)
        })
    return cultural_sites

# %%
queries = load_queries(FILE_NAME)
res = get_cultural_sites(queries=queries, location_name='Aachen')
# res = get_city_info(queries=queries, location_name='Aachen')

# %%
pd.DataFrame(res)
# Out:
#                      siteLabel_en  \
# 0                            None
# 1                Vetschauer Mühle
# 2                            None
# 3               Bleiberger Fabrik
# 4               Bleiberger Fabrik
# 5               Bleiberger Fabrik
# 6               Bleiberger Fabrik
# 7               Bleiberger Fabrik
# 8               Bleiberger Fabrik
# 9                       Colynshof
# 10            Reiff-Museum Aachen
# 11            Burtscheid cemetery
# 12            Burtscheid cemetery
# 13            Burtscheid cemetery
# 14            Burtscheid cemetery
# 15                           None
# 16                           None
# 17                           None
# 18                   Rote Kaserne
# 19             Albert-Vahle-Halle
# 20        Suermondt-Ludwig-Museum
# 21                           None
# 22                       Wandlaus
# 23                           None
# 24                  Friedhof Hüls
# 25                           None
# 26                           None
# 27                         SuperC
# 28  Kunst aus Nordrhein-Westfalen
# 29                           None
# 30                        Klenkes
# 31             Ostfriedhof Aachen
# 32      Abteimühle Kornelimünster
# 33                   Westfriedhof
# 34                           None
# 35          Deutsche Bank Stadion
# 36                 Kongreßdenkmal
# 37            Königsmühle Walheim
# 38              Klosterrather Hof
# 39              Klosterrather Hof
# 40                           None
# 41            Friedhof Güldenplan
# 42             Frankenberg Castle
# 43                           None
# 44                           None
# 45     Tuchfabrik Marx & Auerbach
# 46                           None
# 47                           None
# 48                           None
# 49                           None
#
#                                     siteLabel_de  \
# 0                                    Wespienhaus
# 1                               Vetschauer Mühle
# 2                       Klostermühle Brandenburg
# 3                              Bleiberger Fabrik
# 4                              Bleiberger Fabrik
# 5                              Bleiberger Fabrik
# 6                              Bleiberger Fabrik
# 7                              Bleiberger Fabrik
# 8                              Bleiberger Fabrik
# 9                                      Colynshof
# 10                                  Reiff-Museum
# 11            Heißbergfriedhof Burtscheid/Aachen
# 12            Heißbergfriedhof Burtscheid/Aachen
# 13            Heißbergfriedhof Burtscheid/Aachen
# 14            Heißbergfriedhof Burtscheid/Aachen
# 15                                Gut Branderhof
# 16                              Villa Cassalette
# 17                                  Londoner Hof
# 18                                  Rote Kaserne
# 19                            Albert-Vahle-Halle
# 20                       Suermondt-Ludwig-Museum
# 21                             Haarbachtalbrücke
# 22                                      Wandlaus
# 23                                Friedhof Forst
# 24                                 Friedhof Hüls
# 25                                   Quirinusbad
# 26                                     Postwagen
# 27                                        SuperC
# 28  Kunsthaus Nordrhein-Westfalen Kornelimünster
# 29                               Großer Neuenhof
# 30                                       Klenkes
# 31                                   Ostfriedhof
# 32                     Abteimühle Kornelimünster
# 33                         Westfriedhof (Aachen)
# 34                                Kriegerdenkmal
# 35                         Deutsche Bank Stadion
# 36                                Kongreßdenkmal
# 37                           Königsmühle Walheim
# 38                              Klosterather Hof
# 39                              Klosterather Hof
# 40                     Annuntiatenkloster Aachen
# 41                           Friedhof Güldenplan
# 42   Museum für Stadtgeschichte und Kunstgewerbe
# 43                                   Wespienhaus
# 44                                   Wespienhaus
# 45                               Marx & Auerbach
# 46                        Friedhof Nirmer Straße
# 47                            Zollhaus Königstor
# 48                              Burghaus Classen
# 49                                  Haus Brüssel
#
#                                        description_en  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                  museum in Germany
# 11                        cemetery in Aachen, Germany
# 12                        cemetery in Aachen, Germany
# 13                        cemetery in Aachen, Germany
# 14                        cemetery in Aachen, Germany
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                      art museum in Aachen, Germany
# 21                                               None
# 22                                               None
# 23                        cemetery in Aachen, Germany
# 24                        cemetery in Aachen, Germany
# 25                                               None
# 26                                               None
# 27  building complex that belongs to the RWTH Aach...
# 28                                             museum
# 29                                               None
# 30                            architectural structure
# 31                        cemetery in Aachen, Germany
# 32                                               None
# 33                        cemetery in Aachen, Germany
# 34                        monument in Aachen, Germany
# 35                            architectural structure
# 36                        monument in Aachen, Germany
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                       graveyard in Aachen, Germany
# 42  German museum (hosted in a castle of the same ...
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                            architectural structure
# 49                                               None
#
#                                        description_de  \
# 0   ehemaliges historisches barockes Bürgerhaus in...
# 1                                                None
# 2   Wassermühle am Iterbach in Aachen-Sief, Nordrh...
# 3                       Bildungseinrichtung in Aachen
# 4                       Bildungseinrichtung in Aachen
# 5                       Bildungseinrichtung in Aachen
# 6                       Bildungseinrichtung in Aachen
# 7                       Bildungseinrichtung in Aachen
# 8                       Bildungseinrichtung in Aachen
# 9                   ehemaliger Gutshof in Deutschland
# 10        ehemaliges Museum, Institut der RWTH Aachen
# 11  1862 eingeweihter Friedhof in der damaligen ei...
# 12  1862 eingeweihter Friedhof in der damaligen ei...
# 13  1862 eingeweihter Friedhof in der damaligen ei...
# 14  1862 eingeweihter Friedhof in der damaligen ei...
# 15             ehemaliges Hofgut in Aachen-Burtscheid
# 16                                               None
# 17                               historisches Gebäude
# 18                             Bauwerk in Deutschland
# 19     Reithalle des Aachen-Laurensberger-Rennvereins
# 20                              Kunstmuseum in Aachen
# 21   Autobahnbrücke der Bundesautobahn 544 bei Aachen
# 22  speziell für die Verteidigung präparierter his...
# 23                                 Friedhof in Aachen
# 24                                 Friedhof in Aachen
# 25                       Bad in der Aachener Altstadt
# 26                           Gebäudekomplex in Aachen
# 27  moderner Gebäudekomplex für das Service-Zentru...
# 28                              Museum in Deutschland
# 29        historische Hofanlage in Aachen Laurensberg
# 30  Erkennungszeichen der Aachener und Brunnen in ...
# 31                    Friedhof in Aachen, Deutschland
# 32  Wassermühle an dem Bach Inde in Aachen-Korneli...
# 33                            Friedhof in Deutschland
# 34                             Denkmal in Deutschland
# 35                             Bauwerk in Deutschland
# 36  Baudenkmal zu Ehren des Monarchenkongresses 18...
# 37          Wassermühle am Iterbach in Aachen-Walheim
# 38  früheres Kloster und späteres Wohn- und Fabrik...
# 39  früheres Kloster und späteres Wohn- und Fabrik...
# 40    Kloster eines römisch-katholischen Frauenordens
# 41                                 Friedhof in Aachen
# 42                    bis 2010 Heimatmuseum in Aachen
# 43  ehemaliges historisches barockes Bürgerhaus in...
# 44  ehemaliges historisches barockes Bürgerhaus in...
# 45                               Tuchfabrik in Aachen
# 46           Friedhof im Aachener Stadtteil Eilendorf
# 47                                               None
# 48                großbürgerliches Wohnhaus in Aachen
# 49                                               None
#
#                                                 image
# 0   http://commons.wikimedia.org/wiki/Special:File...
# 1   http://commons.wikimedia.org/wiki/Special:File...
